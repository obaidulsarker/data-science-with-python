# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'data\uci breast cancer dataset.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df = df.drop(['id','Unnamed: 32'], axis = 'columns')

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
sns.countplot(x='diagnosis',data=df)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
df.diagnosis.value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
# Create the countplot
plt.figure(figsize=(8, 6))
ax = sns.countplot(x='diagnosis', data=df, palette='Set2')

# Annotate the bars with their respective counts
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2, height), ha='center', va='bottom', fontsize=12)

# Optionally, you can set the y-axis label
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
x = df.drop('diagnosis',axis=1)

# %%
y = df[['diagnosis']]

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, random_state=42, test_size=.30)

# %%
ytest
# Out:
#     diagnosis
# 204         B
# 70          M
# 131         M
# 431         B
# 540         B
# ..        ...
# 69          B
# 542         B
# 176         B
# 501         M
# 247         B
#
# [171 rows x 1 columns]

# %%
ytest.shape
# Out:
# (171, 1)

# %%
xtest.shape
# Out:
# (171, 30)

# %% [markdown]
# # Test and Validation

# %%
x_test, x_val, y_test, y_val = train_test_split(xtest, ytest, random_state=42, test_size=.50)
x_test.shape #15% of total data
# Out:
# (85, 30)

# %%
x_val.shape #15% of total data ; for hyper param tuning
# Out:
# (86, 30)

# %% [markdown]
# # Step 3: Decision Tree model and evaluation

# %%
dt_model = DecisionTreeClassifier(random_state=1)
dt_model.fit(xtrain, ytrain)
y_pred_dt = dt_model.predict(xtest)

# %%
y_pred_dt
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B'], dtype=object)

# %% [markdown]
# # Evaluate Decision Tree model performance

# %%
print("Decision Tree Model Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_dt), '\n')
print("Classification Report:")
print(classification_report(ytest, y_pred_dt))
# Out:
# Decision Tree Model Performance:
# Accuracy: 0.935672514619883
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.96      0.94      0.95       108
#            M       0.89      0.94      0.91        63
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.94      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %% [markdown]
# # Step 4: Random Forest model and evaluation

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(xtrain, ytrain)
y_pred_rf = rf_model.predict(xtest)

# %%
y_pred_rf
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B'], dtype=object)

# %% [markdown]
# # Evaluate Random Forest model performance

# %%
print("\nRandom Forest Model Performance:") 
print("Accuracy:", accuracy_score(ytest, y_pred_rf), '\n') 
print("Classification Report:") 
print(classification_report(ytest, y_pred_rf))
# Out:
# Random Forest Model Performance:
# Accuracy: 0.9707602339181286
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.96      0.99      0.98       108
#            M       0.98      0.94      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %% [markdown]
# # Pre - Pruning for Cost Complexity

# %% [markdown]
# # Initialized Hyperparameters

# %%
# Define hyperparameters for Decision Tree 
dt_params = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 2,4,6,8,10,15,20,25,28],
    'min_samples_split': [1, 2,3,4,5,6,7,10],
    'min_samples_leaf': [1,2,3,4,5]
}

#Define hyperparameters for Random Forest
rf_params = {
    'n_estimators': [101, 151, 201, 251, 301],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 2,4,6,8,10,15,20,25,28],
    'min_samples_split': [2,3,4,5,6,7,810],
    'min_samples_leaf': [1, 2,3, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
# Perform Grid Search for Decision Tree
dt_grid_search = GridSearchCV(estimator=DecisionTreeClassifier(random_state=42),
                              param_grid=dt_params, cv=5)
dt_grid_search.fit(xtrain, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 2, 4, 6, 8, 10, 15, 20, 25, 28],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [1, 2, 3, 4, 5, 6, 7, 10],
#                          'splitter': ['best', 'random']})

# %%
dt_grid_search.cv_results_
# Out:
# {'mean_fit_time': array([0.00079684, 0.00092402, 0.01563902, ..., 0.00356512, 0.0119802 ,
#         0.00357389]),
#  'std_fit_time': array([0.00039842, 0.000205  , 0.00114557, ..., 0.000582  , 0.00108127,
#         0.00047629]),
#  'mean_score_time': array([0.        , 0.        , 0.00457368, ..., 0.00336404, 0.00423102,
#         0.00401096]),
#  'std_score_time': array([0.        , 0.        , 0.00100327, ..., 0.00045831, 0.00097269,
#         0.0011107 ]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', ..., 'entropy', 'entropy',
#                     'entropy'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[None, None, None, ..., 28, 28, 28],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[1, 1, 1, ..., 5, 5, 5],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[1, 1, 2, ..., 7, 10, 10],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', ..., 'random', 'best',
#                     'random'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'gini',
#    'max_depth': 8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
# ...
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': None,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 2,
#    'min_samples_leaf': 5,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 5,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 1,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 2,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3,
#    'splitter': 'random'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'best'},
#   {'criterion': 'entropy',
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 4,
#    'splitter': 'random'},
#   ...],
#  'split0_test_score': array([   nan,    nan, 0.9125, ..., 0.925 , 0.925 , 0.925 ]),
#  'split1_test_score': array([   nan,    nan, 0.8875, ..., 0.875 , 0.8875, 0.875 ]),
#  'split2_test_score': array([   nan,    nan, 0.9   , ..., 0.925 , 0.9625, 0.925 ]),
#  'split3_test_score': array([       nan,        nan, 0.93670886, ..., 0.88607595, 0.94936709,
#         0.88607595]),
#  'split4_test_score': array([       nan,        nan, 0.91139241, ..., 0.86075949, 0.92405063,
#         0.86075949]),
#  'mean_test_score': array([       nan,        nan, 0.90962025, ..., 0.89436709, 0.92968354,
#         0.89436709]),
#  'std_test_score': array([       nan,        nan, 0.0162916 , ..., 0.02626803, 0.02568065,
#         0.02626803]),
#  'rank_test_score': array([1401, 1401, 1079, ..., 1303,  243, 1303])}

# %%
tuning_result_dt_gs = pd.DataFrame(dt_grid_search.cv_results_)
tuning_result_dt_gs
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.000797      0.000398         0.000000        0.000000
# 1          0.000924      0.000205         0.000000        0.000000
# 2          0.015639      0.001146         0.004574        0.001003
# 3          0.004769      0.000393         0.005204        0.000392
# 4          0.016151      0.002753         0.004594        0.000790
# ...             ...           ...              ...             ...
# 1595       0.003191      0.000399         0.004189        0.000400
# 1596       0.012183      0.000974         0.004003        0.001081
# 1597       0.003565      0.000582         0.003364        0.000458
# 1598       0.011980      0.001081         0.004231        0.000973
# 1599       0.003574      0.000476         0.004011        0.001111
#
#      param_criterion param_max_depth param_min_samples_leaf  \
# 0               gini            None                      1
# 1               gini            None                      1
# 2               gini            None                      1
# 3               gini            None                      1
# 4               gini            None                      1
# ...              ...             ...                    ...
# 1595         entropy              28                      5
# 1596         entropy              28                      5
# 1597         entropy              28                      5
# 1598         entropy              28                      5
# 1599         entropy              28                      5
#
#      param_min_samples_split param_splitter  \
# 0                          1           best
# 1                          1         random
# 2                          2           best
# 3                          2         random
# 4                          3           best
# ...                      ...            ...
# 1595                       6         random
# 1596                       7           best
# 1597                       7         random
# 1598                      10           best
# 1599                      10         random
#
#                                                  params  split0_test_score  \
# 0     {'criterion': 'gini', 'max_depth': None, 'min_...                NaN
# 1     {'criterion': 'gini', 'max_depth': None, 'min_...                NaN
# 2     {'criterion': 'gini', 'max_depth': None, 'min_...             0.9125
# 3     {'criterion': 'gini', 'max_depth': None, 'min_...             0.9375
# 4     {'criterion': 'gini', 'max_depth': None, 'min_...             0.9125
# ...                                                 ...                ...
# 1595  {'criterion': 'entropy', 'max_depth': 28, 'min...             0.9250
# 1596  {'criterion': 'entropy', 'max_depth': 28, 'min...             0.9250
# 1597  {'criterion': 'entropy', 'max_depth': 28, 'min...             0.9250
# 1598  {'criterion': 'entropy', 'max_depth': 28, 'min...             0.9250
# 1599  {'criterion': 'entropy', 'max_depth': 28, 'min...             0.9250
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                0.8875             0.9000           0.936709
# 3                0.9000             0.9625           0.911392
# 4                0.8875             0.9000           0.936709
# ...                 ...                ...                ...
# 1595             0.8750             0.9250           0.886076
# 1596             0.8875             0.9625           0.949367
# 1597             0.8750             0.9250           0.886076
# 1598             0.8875             0.9625           0.949367
# 1599             0.8750             0.9250           0.886076
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                   NaN              NaN             NaN             1401
# 1                   NaN              NaN             NaN             1401
# 2              0.911392         0.909620        0.016292             1079
# 3              0.949367         0.932152        0.023284              213
# 4              0.911392         0.909620        0.016292             1079
# ...                 ...              ...             ...              ...
# 1595           0.860759         0.894367        0.026268             1303
# 1596           0.924051         0.929684        0.025681              243
# 1597           0.860759         0.894367        0.026268             1303
# 1598           0.924051         0.929684        0.025681              243
# 1599           0.860759         0.894367        0.026268             1303
#
# [1600 rows x 18 columns]

# %%
tuning_result_dt_gs.shape
# Out:
# (1600, 18)

# %%
dt_grid_search.best_params_ #clf = dt_grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'splitter': 'best'}

# %%
tuning_result_dt_gs.sort_values('rank_test_score').head(5)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 980       0.019825      0.003266         0.005706        0.001045
# 978       0.020762      0.003136         0.006777        0.001462
# 982       0.014750      0.001180         0.004399        0.000500
# 986       0.014557      0.001482         0.004803        0.000392
# 988       0.017349      0.003023         0.005782        0.000731
#
#     param_criterion param_max_depth param_min_samples_leaf  \
# 980         entropy               4                      2
# 978         entropy               4                      2
# 982         entropy               4                      2
# 986         entropy               4                      2
# 988         entropy               4                      2
#
#     param_min_samples_split param_splitter  \
# 980                       3           best
# 978                       2           best
# 982                       4           best
# 986                       6           best
# 988                       7           best
#
#                                                 params  split0_test_score  \
# 980  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
# 978  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
# 982  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
# 986  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
# 988  {'criterion': 'entropy', 'max_depth': 4, 'min_...             0.9375
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 980                0.9              0.975           0.949367
# 978                0.9              0.975           0.949367
# 982                0.9              0.975           0.949367
# 986                0.9              0.975           0.949367
# 988                0.9              0.975           0.949367
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 980           0.936709         0.939715        0.024205                1
# 978           0.936709         0.939715        0.024205                1
# 982           0.936709         0.939715        0.024205                1
# 986           0.936709         0.939715        0.024205                1
# 988           0.936709         0.939715        0.024205                1

# %% [markdown]
# # Perform Grid Search for Random Forest

# %% [markdown]
# rf_grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42),
#                               param_grid=rf_params, cv=5)
# rf_grid_search.fit(xtrain, ytrain)

# %% [markdown]
# # Evaluate the optimized models

# %%
# Decision Tree and Grid Search
y_pred_dt_gs = dt_grid_search.predict(xtest)
print("\nDecision Tree Grid Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_dt_gs))
print("Classification Report:")
print(classification_report(ytest, y_pred_dt_gs))
# Out:
# Decision Tree Grid Search Performance:
# Accuracy: 0.9532163742690059
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.95      0.98      0.96       108
#            M       0.97      0.90      0.93        63
#
#     accuracy                           0.95       171
#    macro avg       0.96      0.94      0.95       171
# weighted avg       0.95      0.95      0.95       171

# %% [markdown]
# # Random Forest Grid Search
# y_pred_rf_gs = rf_grid_search.predict(xtest)
# print("\nRandom Forest Grid Search Performance:")
# print("Accuracy:", accuracy_score(ytest, y_pred_rf_gs))
# print("Classification Report:")
# print(classification_report(ytest, y_pred_rf_gs))

# %% [markdown]
# # Hyperparameter optimization using Randomized Search for Decision Tree

# %%
# Perform Randomized Search for Decision Tree
dt_random_search = RandomizedSearchCV(estimator=DecisionTreeClassifier(random_state=42),
                                      param_distributions=dt_params, n_iter=100, cv=5, random_state=42)
dt_random_search.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                    n_iter=100,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 2, 4, 6, 8, 10, 15,
#                                                       20, 25, 28],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         
#         6.25718230e-04, 4.83651240e-04, 1.37072110e-03, 4.97320363e-04,
#         7.45539931e-04, 1.38777775e-03, 4.59033070e-04, 7.65850866e-04,
#         0.00000000e+00, 5.24448854e-04, 5.06048857e-04, 6.22842761e-04,
#         3.98717722e-04, 3.94994685e-04, 4.88753282e-04, 1.14892276e-03,
#         4.83382587e-04, 4.52138316e-04, 9.62000591e-04, 5.09154763e-04,
#         4.81079934e-04, 8.59170850e-05, 5.09007293e-04, 4.08225719e-04,
#         0.00000000e+00, 0.00000000e+00, 3.89364388e-04, 7.38791301e-04,
#         6.61411597e-04, 0.00000000e+00, 4.88383066e-04, 4.83716916e-04,
#         5.03887938e-04, 4.03695317e-04, 4.76098743e-04, 9.98210599e-04,
#         4.87974478e-04, 4.13182108e-04, 1.33999555e-03, 3.98872484e-04,
#         5.29896315e-04, 4.74067930e-04, 4.54052895e-04, 4.87009302e-04,
#         4.82283285e-04, 4.35965254e-04, 7.59832936e-04, 7.40444679e-04,
#         4.96505623e-04, 0.00000000e+00, 9.41638739e-04, 6.96582983e-04]),
#  'param_splitter': masked_array(data=['best', 'best', 'best', 'random', 'random', 'best',
#                     'random', 'random', 'best', 'best', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'best',
#                     'random', 'best', 'random', 'random', 'best', 'best',
#                     'random', 'best', 'best', 'best', 'best', 'best',
#                     'best', 'random', 'random', 'best', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'random', 'random', 'random', 'best', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'random', 'best',
#                     'random', 'best', 'best', 'best', 'random', 'random',
#                     'best', 'random', 'random', 'best', 'best', 'random',
#                     'best', 'best', 'random', 'random', 'best', 'random',
#                     'random', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'random', 'random', 'best', 'random',
#                     'random', 'random', 'best', 'best', 'best', 'best',
#                     'best', 'best', 'random', 'random', 'best', 'random',
#                     'random', 'random', 'best', 'best'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[10, 2, 5, 4, 5, 5, 3, 7, 10, 6, 2, 10, 5, 1, 5, 1, 10,
#                     5, 10, 10, 10, 3, 7, 4, 7, 4, 10, 6, 7, 5, 4, 1, 6, 4,
#                     1, 10, 3, 5, 7, 7, 6, 7, 1, 4, 2, 1, 4, 2, 4, 2, 5, 4,
#                     4, 6, 2, 7, 1, 6, 10, 2, 7, 3, 3, 7, 10, 6, 7, 6, 4, 3,
#                     7, 10, 1, 1, 3, 2, 2, 1, 4, 3, 3, 2, 4, 4, 10, 4, 6, 7,
#                     5, 2, 7, 4, 3, 4, 2, 5, 2, 1, 6, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[3, 3, 1, 4, 4, 2, 4, 5, 5, 1, 3, 4, 1, 4, 2, 5, 2, 2,
#                     3, 1, 3, 1, 2, 4, 2, 2, 5, 2, 1, 5, 5, 4, 2, 1, 2, 3,
#                     1, 4, 4, 1, 5, 4, 1, 2, 1, 3, 1, 2, 3, 5, 5, 4, 1, 5,
#                     3, 1, 3, 1, 1, 4, 4, 5, 4, 5, 4, 4, 5, 4, 3, 3, 1, 3,
#                     3, 2, 1, 1, 4, 3, 2, 5, 1, 5, 3, 4, 3, 2, 4, 3, 2, 4,
#                     3, 4, 1, 5, 4, 2, 5, 4, 5, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[15, 8, 4, 2, 2, 28, 10, 4, 10, 25, 15, 6, 4, 28, 20,
#                     None, None, 2, 8, 8, 25, 15, 28, 8, None, 8, 2, 25, 8,
#                     25, None, 6, 4, 28, 10, 6, 8, 20, 8, 4, 20, 25, 28,
#                     None, 28, None, 20, 2, 15, 8, 15, 8, None, 8, 20, 25,
#                     8, 20, 10, 20, 6, None, 25, 4, 28, None, 20, 4, 28, 25,
#                     15, 15, 28, None, 6, 6, 20, 6, 25, 20, 10, 6, 20, 15,
#                     28, 15, 6, 28, 8, 15, 6, 15, 15, 10, 20, 4, 25, None,
#                     6, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'entropy',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'entropy', 'entropy', 'gini',
#                     'entropy', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'entropy',
#                     'entropy', 'gini', 'entropy', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'entropy', 'gini', 'entropy',
#                     'gini', 'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'gini', 'entropy', 'entropy',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'gini', 'entropy', 'gini',
#                     'entropy', 'entropy', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'gini', 'entropy', 'entropy', 'gini',
#                     'gini', 'gini', 'gini', 'entropy', 'gini', 'entropy',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'entropy',
#                     'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 4,
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 5,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 1,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 4,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 5,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 2,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 2,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 2,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 5,
#    'max_depth': 2,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 2,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 1,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 5,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 5,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 4,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 2,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 1,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 1,
#    'min_samples_leaf': 2,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 4,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 1,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 5,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 7,
#    'min_samples_leaf': 4,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 1,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 2,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 1,
#    'min_samples_leaf': 3,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 1,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_depth': 2,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 5,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 5,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 8,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 1,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 5,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 3,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 1,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 1,
#    'min_samples_leaf': 3,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 1,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 4,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 5,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 4,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 6,
#    'min_samples_leaf': 4,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 5,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 4,
#    'max_depth': 4,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 3,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 1,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 2,
#    'max_depth': None,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 3,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 2,
#    'max_depth': 25,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 5,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 10,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 5,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 3,
#    'max_depth': 20,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 10,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 2,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 4,
#    'max_depth': 6,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 3,
#    'max_depth': 28,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 8,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 7,
#    'min_samples_leaf': 3,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 4,
#    'min_samples_leaf': 4,
#    'max_depth': 15,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 3,
#    'min_samples_leaf': 1,
#    'max_depth': 15,
#    'criterion': 'entropy'},
#   {'splitter': 'random',
#    'min_samples_split': 4,
#    'min_samples_leaf': 5,
#    'max_depth': 10,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_depth': 20,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_depth': 4,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 2,
#    'min_samples_leaf': 5,
#    'max_depth': 25,
#    'criterion': 'gini'},
#   {'splitter': 'random',
#    'min_samples_split': 1,
#    'min_samples_leaf': 4,
#    'max_depth': None,
#    'criterion': 'gini'},
#   {'splitter': 'best',
#    'min_samples_split': 6,
#    'min_samples_leaf': 5,
#    'max_depth': 6,
#    'criterion': 'entropy'},
#   {'splitter': 'best',
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_depth': None,
#    'criterion': 'entropy'}],
#  'split0_test_score': array([0.9375, 0.95  , 0.9375, 0.9125, 0.9125, 0.95  , 0.9125, 0.95  ,
#         0.9375, 0.9375, 0.95  , 0.9   , 0.9375,    nan, 0.9125,    nan,
#         0.9375, 0.9375, 0.9   , 0.9375, 0.8875, 0.95  , 0.925 , 0.95  ,
#         0.9375, 0.95  , 0.9375, 0.925 , 0.9375, 0.9375, 0.9375,    nan,
#         0.9375, 0.95  ,    nan, 0.9375, 0.9125, 0.925 , 0.95  , 0.95  ,
#         0.9375, 0.925 ,    nan, 0.875 , 0.925 ,    nan, 0.9125, 0.9125,
#         0.95  , 0.925 , 0.925 , 0.9125, 0.925 , 0.9375, 0.9375, 0.925 ,
#            nan, 0.9375, 0.9375, 0.925 , 0.95  , 0.9375, 0.9125, 0.9375,
#         0.9375, 0.925 , 0.9375, 0.9375, 0.925 , 0.925 , 0.925 , 0.9   ,
#            nan,    nan, 0.9125, 0.9375, 0.95  ,    nan, 0.95  , 0.925 ,
#         0.925 , 0.9   , 0.925 , 0.925 , 0.8875, 0.9375, 0.95  , 0.95  ,
#         0.9125, 0.95  , 0.925 , 0.95  , 0.925 , 0.9375, 0.95  , 0.9375,
#         0.9375,    nan, 0.925 , 0.95  ]),
#  'split1_test_score': array([0.9   , 0.9   , 0.9   , 0.8375, 0.8375, 0.8875, 0.875 , 0.875 ,
#         0.8875, 0.8875, 0.9   , 0.875 , 0.9   ,    nan, 0.9125,    nan,
#         0.9   , 0.9   , 0.875 , 0.8875, 0.875 , 0.9   , 0.8875, 0.9125,
#         0.9   , 0.9   , 0.8875, 0.8875, 0.8875, 0.8875, 0.8875,    nan,
#         0.8625, 0.9   ,    nan, 0.875 , 0.8875, 0.875 , 0.9125, 0.8875,
#         0.8875, 0.875 ,    nan, 0.875 , 0.8875,    nan, 0.8875, 0.8375,
#         0.9   , 0.875 , 0.8875, 0.875 , 0.8875, 0.8875, 0.9   , 0.8875,
#            nan, 0.8875, 0.8875, 0.875 , 0.9125, 0.875 , 0.875 , 0.8875,
#         0.8875, 0.875 , 0.8875, 0.8875, 0.8875, 0.8875, 0.8875, 0
#         0.02877144, 0.0162916 , 0.03255473, 0.01495252, 0.02281257,
#         0.01684989, 0.03255473,        nan, 0.03434843, 0.02417697,
#                nan, 0.01732126, 0.03824736, 0.02905498, 0.02626803,
#         0.02568065, 0.03088306, 0.01694472, 0.01684989, 0.04904845,
#         0.02281257,        nan, 0.01822054, 0.02168878, 0.03255473,
#         0.01495252, 0.03660428, 0.03088306, 0.02894236, 0.01684989,
#         0.03255473, 0.01684989, 0.02894236, 0.0267143 , 0.0267143 ,
#         0.02281257, 0.03727768,        nan,        nan, 0.01556647,
#         0.0232441 , 0.0266957 ,        nan, 0.01833216, 0.02626803,
#         0.01694472, 0.0181801 , 0.01980527, 0.03255473, 0.03198019,
#         0.02709434, 0.01495252, 0.0298063 , 0.0144192 , 0.01495252,
#         0.02067219, 0.01495252, 0.01694472, 0.03660428, 0.01495252,
#         0.03424463, 0.03660428,        nan, 0.02568065, 0.01833216]),
#  'rank_test_score': array([39, 58, 29, 82, 89, 10, 26, 29, 47, 43, 58, 84,  2, 90, 29, 90, 47,
#         46, 69,  3, 56,  1, 19, 11, 24,  3, 61, 19, 43, 47, 47, 90, 65, 18,
#         90, 25, 74, 76, 11, 29, 47, 76, 90, 67, 41, 90, 65, 82, 58, 86, 21,
#         26, 62, 47, 85, 29, 90, 43, 21, 76, 11, 71, 26,  3, 47, 76, 47,  3,
#         36, 36, 29, 69, 90, 90, 67, 47,  3, 90,  3, 86, 62, 88, 41, 76, 56,
#         81, 11, 40, 29, 11, 38, 11, 62, 71, 11, 75, 71, 90, 21,  3])}

# %%
tuning_result_dt_rs = pd.DataFrame(dt_random_search.cv_results_)
tuning_result_dt_rs
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.015504      0.001932         0.005846        0.000686
# 1        0.017964      0.002896         0.005973        0.001238
# 2        0.015755      0.001935         0.004987        0.000633
# 3        0.005446      0.000618         0.006097        0.000679
# 4        0.004587      0.000475         0.005141        0.000305
# ..            ...           ...              ...             ...
# 95       0.004022      0.000066         0.004755        0.000740
# 96       0.004031      0.000046         0.004555        0.000497
# 97       0.000396      0.000485         0.000000        0.000000
# 98       0.014621      0.001928         0.004869        0.000942
# 99       0.016764      0.001582         0.005212        0.000697
#
#    param_splitter param_min_samples_split param_min_samples_leaf  \
# 0            best                      10                      3
# 1            best                       2                      3
# 2            best                       5                      1
# 3          random                       4                      4
# 4          random                       5                      4
# ..            ...                     ...                    ...
# 95         random                       5                      2
# 96         random                       2                      5
# 97         random                       1                      4
# 98           best                       6                      5
# 99           best                       2                      2
#
#    param_max_depth param_criterion  \
# 0               15            gini
# 1                8            gini
# 2                4            gini
# 3                2            gini
# 4                2         entropy
# ..             ...             ...
# 95               4            gini
# 96              25            gini
# 97            None            gini
# 98               6         entropy
# 99            None         entropy
#
#                                                params  split0_test_score  \
# 0   {'splitter': 'best', 'min_samples_split': 10, ...             0.9375
# 1   {'splitter': 'best', 'min_samples_split': 2, '...             0.9500
# 2   {'splitter': 'best', 'min_samples_split': 5, '...             0.9375
# 3   {'splitter': 'random', 'min_samples_split': 4,...             0.9125
# 4   {'splitter': 'random', 'min_samples_split': 5,...             0.9125
# ..                                                ...                ...
# 95  {'splitter': 'random', 'min_samples_split': 5,...             0.9375
# 96  {'splitter': 'random', 'min_samples_split': 2,...             0.9375
# 97  {'splitter': 'random', 'min_samples_split': 1,...                NaN
# 98  {'splitter': 'best', 'min_samples_split': 6, '...             0.9250
# 99  {'splitter': 'best', 'min_samples_split': 2, '...             0.9500
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0              0.9000             0.9250           0.924051
# 1              0.9000             0.8750           0.949367
# 2              0.9000             0.9250           0.936709
# 3              0.8375             0.9500           0.886076
# 4              0.8375             0.8625           0.873418
# ..                ...                ...                ...
# 95             0.8625             0.9125           0.949367
# 96             0.8750             0.9500           0.936709
# 97                NaN                NaN                NaN
# 98             0.8875             0.9625           0.949367
# 99             0.9000             0.9500           0.936709
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.936709         0.924652        0.013555               39
# 1            0.911392         0.917152        0.029055               58
# 2            0.936709         0.927184        0.014364               29
# 3            0.924051         0.902025        0.038247               82
# 4            0.924051         0.881994        0.032040               89
# ..                ...              ...             ...              ...
# 95           0.873418         0.907057        0.034245               75
# 96           0.860759         0.911994        0.036604               71
# 97                NaN              NaN             NaN               90
# 98           0.924051         0.929684        0.025681               21
# 99           0.936709         0.934684        0.018332                3
#
# [100 rows x 18 columns]

# %%
dt_random_search.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 3,
#  'min_samples_leaf': 1,
#  'max_depth': 15,
#  'criterion': 'gini'}

# %% [markdown]
# # Perform Randomized Search for Random Forest

# %%
rf_random_search = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42),
                                      param_distributions=rf_params, n_iter=100, cv=5, random_state=42)
rf_random_search.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 2, 4, 6, 8, 10, 15,
#                                                       20, 25, 28],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 3, 4],
#                                         'min_samples_split': [2, 3, 4, 5, 6, 7,
#                                                               810],
#                                         'n_estimators': [101, 151, 201, 251,
#                                                          301]},
#                    random_state=42)

# %%
rf_random_search.cv_results_
tuning_result_rf_rs = pd.DataFrame(rf_random_search.cv_results_)
tuning_result_rf_rs
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000691      0.000438         0.000000        0.000000
# 1        0.237834      0.012323         0.025500        0.003219
# 2        0.470610      0.016519         0.031917        0.005284
# 3        0.707590      0.034173         0.037082        0.004124
# 4        0.000623      0.000510         0.000000        0.000000
# ..            ...           ...              ...             ...
# 95       0.448455      0.025426         0.025338        0.003777
# 96       0.563969      0.037795         0.026884        0.001494
# 97       0.454342      0.028223         0.043298        0.004569
# 98       0.000542      0.000455         0.000000        0.000000
# 99       0.000635      0.000436         0.000000        0.000000
#
#    param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                 251                     810                      1
# 1                 151                     810                      3
# 2                 201                       4                      1
# 3                 251                       3                      3
# 4                 151                     810                      4
# ..                ...                     ...                    ...
# 95                151                       4                      1
# 96                201                       3                      2
# 97                301                     810                      1
# 98                201                       7                      2
# 99                251                       3                      4
#
#    param_max_features param_max_depth param_criterion  \
# 0                auto            None            gini
# 1                sqrt               4         entropy
# 2                log2               2         entropy
# 3                log2              20            gini
# 4                auto               2         entropy
# ..                ...             ...             ...
# 95               log2              28            gini
# 96               log2              28            gini
# 97               sqrt              20            gini
# 98               auto              15         entropy
# 99               auto               4         entropy
#
#                                                params  split0_test_score  \
# 0   {'n_estimators': 251, 'min_samples_split': 810...                NaN
# 1   {'n_estimators': 151, 'min_samples_split': 810...             0.6250
# 2   {'n_estimators': 201, 'min_samples_split': 4, ...             0.9375
# 3   {'n_estimators': 251, 'min_samples_split': 3, ...             0.9500
# 4   {'n_estimators': 151, 'min_samples_split': 810...                NaN
# ..                                                ...                ...
# 95  {'n_estimators': 151, 'min_samples_split': 4, ...             0.9375
# 96  {'n_estimators': 201, 'min_samples_split': 3, ...             0.9375
# 97  {'n_estimators': 301, 'min_samples_split': 810...             0.6250
# 98  {'n_estimators': 201, 'min_samples_split': 7, ...                NaN
# 99  {'n_estimators': 251, 'min_samples_split': 3, ...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1              0.6250             0.6250           0.632911
# 2              0.9375             0.9375           0.936709
# 3              0.9500             0.9625           0.936709
# 4                 NaN                NaN                NaN
# ..                ...                ...                ...
# 95             0.9500             0.9625           0.936709
# 96             0.9500             0.9625           0.936709
# 97             0.6250             0.6250           0.632911
# 98                NaN                NaN                NaN
# 99                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               68
# 1            0.620253         0.625633        0.004077               57
# 2            0.924051         0.934652        0.005309               52
# 3            0.949367         0.949715        0.008160               15
# 4                 NaN              NaN             NaN               68
# ..                ...              ...             ...              ...
# 95           0.924051         0.942152        0.013073               50
# 96           0.949367         0.947215        0.009495               28
# 97           0.620253         0.625633        0.004077               57
# 98                NaN              NaN             NaN               68
# 99                NaN              NaN             NaN               68
#
# [100 rows x 19 columns]

# %%
rf_random_search.best_params_
# Out:
# {'n_estimators': 201,
#  'min_samples_split': 4,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 8,
#  'criterion': 'gini'}

# %% [markdown]
# # Evaluate the optimized models for Randomized Search

# %% [markdown]
# # Decision Tree Randomized Search

# %%
y_pred_dt_rs = dt_random_search.predict(xtest)
print("\n Decision Tree Randomized Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_dt_rs))
print("Classification Report:")
print(classification_report(ytest, y_pred_dt_rs))
# Out:
#  Decision Tree Randomized Search Performance:
# Accuracy: 0.9298245614035088
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.95      0.94      0.94       108
#            M       0.89      0.92      0.91        63
#
#     accuracy                           0.93       171
#    macro avg       0.92      0.93      0.93       171
# weighted avg       0.93      0.93      0.93       171

# %% [markdown]
# # Random Forest Randomized Search

# %%
y_pred_rf_rs = rf_random_search.predict(xtest)
print("\n Random Forest Randomized Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_rf_rs))
print("Classification Report:")
print(classification_report(ytest, y_pred_rf_rs))
# Out:
#  Random Forest Randomized Search Performance:
# Accuracy: 0.9707602339181286
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.96      0.99      0.98       108
#            M       0.98      0.94      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %% [markdown]
# # Post Pruning for Decision Tree

# %%
dt_clf = dt_random_search.best_estimator_
dt_clf
# Out:
# DecisionTreeClassifier(max_depth=15, min_samples_split=3, random_state=42,
#                        splitter='random')

# %%
x.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_clf, filled=True)
# Out:
# [Text(0.4889705882352941, 0.9545454545454546, 'x[7] <= 0.04\ngini = 0.468\nsamples = 398\nvalue = [249, 149]'),
#  Text(0.3235294117647059, 0.8636363636363636, 'x[20] <= 17.727\ngini = 0.079\nsamples = 218\nvalue = [209, 9]'),
#  Text(0.2647058823529412, 0.7727272727272727, 'x[13] <= 86.985\ngini = 0.046\nsamples = 213\nvalue = [208, 5]'),
#  Text(0.23529411764705882, 0.6818181818181818, 'x[12] <= 3.525\ngini = 0.037\nsamples = 212\nvalue = [208, 4]'),
#  Text(0.17647058823529413, 0.5909090909090909, 'x[10] <= 0.245\ngini = 0.029\nsamples = 207\nvalue = [204, 3]'),
#  Text(0.14705882352941177, 0.5, 'x[27] <= 0.125\ngini = 0.061\nsamples = 96\nvalue = [93, 3]'),
#  Text(0.08823529411764706, 0.4090909090909091, 'x[20] <= 14.137\ngini = 0.042\nsamples = 93\nvalue = [91, 2]'),
#  Text(0.058823529411764705, 0.3181818181818182, 'gini = 0.0\nsamples = 69\nvalue = [69, 0]'),
#  Text(0.11764705882352941, 0.3181818181818182, 'x[14] <= 0.006\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.08823529411764706, 0.22727272727272727, 'x[14] <= 0.004\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.058823529411764705, 0.13636363636363635, 'x[21] <= 28.858\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.029411764705882353, 0.045454545454545456, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.08823529411764706, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11764705882352941, 0.13636363636363635, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.14705882352941177, 0.22727272727272727, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20588235294117646, 0.4090909090909091, 'x[17] <= 0.008\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.17647058823529413, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23529411764705882, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20588235294117646, 0.5, 'gini = 0.0\nsamples = 111\nvalue = [111, 0]'),
#  Text(0.29411764705882354, 0.5909090909090909, 'x[19] <= 0.004\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2647058823529412, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3235294117647059, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.29411764705882354, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38235294117647056, 0.7727272727272727, 'x[11] <= 1.379\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.35294117647058826, 0.6818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4117647058823529, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6544117647058824, 0.8636363636363636, 'x[20] <= 15.828\ngini = 0.346\nsamples = 180\nvalue = [40, 140]'),
#  Text(0.5294117647058824, 0.7727272727272727, 'x[27] <= 0.197\ngini = 0.455\nsamples = 40\nvalue = [26, 14]'),
#  Text(0.5, 0.6818181818181818, 'x[28] <= 0.32\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.4117647058823529, 0.5909090909090909, 'x[1] <= 20.057\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.38235294117647056, 0.5, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.4411764705882353, 0.5, 'x[7] <= 0.048\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.4117647058823529, 0.4090909090909091, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.47058823529411764, 0.4090909090909091, 'x[1] <= 21.136\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.4411764705882353, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5882352941176471, 0.5909090909090909, 'x[20] <= 15.171\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.5588235294117647, 0.5, 'x[21] <= 23.805\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5294117647058824, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5882352941176471, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6176470588235294, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5588235294117647, 0.6818181818181818, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7794117647058824, 0.7727272727272727, 'x[7] <= 0.052\ngini = 0.18\nsamples = 140\nvalue = [14, 126]'),
#  Text(0.6764705882352942, 0.6818181818181818, 'x[9] <= 0.058\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.6470588235294118, 0.5909090909090909, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7058823529411765, 0.5909090909090909, 'x[14] <= 0.005\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.6764705882352942, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7352941176470589, 0.5, 'x[26] <= 0.24\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7058823529411765, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7647058823529411, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8823529411764706, 0.6818181818181818, 'x[1] <= 15.007\ngini = 0.075\nsamples = 128\nvalue = [5, 123]'),
#  Text(0.8235294117647058, 0.5909090909090909, 'x[27] <= 0.162\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.7941176470588235, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8529411764705882, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9411764705882353, 0.5909090909090909, 'x[21] <= 22.48\ngini = 0.032\nsamples = 123\nvalue = [2, 121]'),
#  Text(0.9117647058823529, 0.5, 'x[15] <= 0.04\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.8823529411764706, 0.4090909090909091, 'x[7] <= 0.058\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.8529411764705882, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9117647058823529, 0.3181818181818182, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9411764705882353, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9705882352941176, 0.5, 'gini = 0.0\nsamples = 112\nvalue = [0, 112]')]

# %% [markdown]
# Read: #https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html

# %%
pruning_path = dt_clf.cost_complexity_pruning_path(xtrain, ytrain) # clf = DecisionTreeClassifier  
ccp_alpha_values = pruning_path.ccp_alphas

# %%
ccp_alpha_values
# Out:
# array([0.        , 0.00176348, 0.00243218, 0.00329561, 0.00335008,
#        0.00376884, 0.00376884, 0.00382867, 0.0040201 , 0.00446678,
#        0.00481458, 0.00603015, 0.00822718, 0.01016286, 0.01480307,
#        0.0149867 , 0.02786589, 0.04729202, 0.2687389 ])

# %%
clfs_list = []  # save diffrent classifiers
for ccp in ccp_alpha_values:
    clf = DecisionTreeClassifier(random_state=42, ccp_alpha=ccp)
    clf.fit(xtrain, ytrain)
    clfs_list.append(clf)

# %%
clfs_list
# Out:
# [DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.0017634757639127315, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.0024321772933576713, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.0032956108455556884, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.003350083752093802, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.0037688442211055275, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.0037688442211055283, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.0038286671452500607, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.004020100502512562, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.004466778336125069, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.0048145769150473895, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.006030150753768844, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.00822717500102138, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.010162859113494644, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.014803071653222432, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.01498669819686669, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.027865891959799015, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.04729201563372415, random_state=42),
#  DecisionTreeClassifier(ccp_alpha=0.26873890194341976, random_state=42)]

# %%
train_scores = [ clf.score(xtrain, ytrain) for clf in clfs_list ] 
test_scores = [ clf.score(xtest, ytest) for clf in clfs_list ]

# %%
train_scores
# Out:
# [1.0,
#  1.0,
#  1.0,
#  0.9949748743718593,
#  0.992462311557789,
#  0.992462311557789,
#  0.992462311557789,
#  0.992462311557789,
#  0.992462311557789,
#  0.992462311557789,
#  0.992462311557789,
#  0.9899497487437185,
#  0.9824120603015075,
#  0.9824120603015075,
#  0.9597989949748744,
#  0.9597989949748744,
#  0.9396984924623115,
#  0.9246231155778895,
#  0.9246231155778895]

# %%
test_scores
# Out:
# [0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9064327485380117,
#  0.8947368421052632,
#  0.8947368421052632]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Alpha")
ax.set_ylabel("Accuracy")

ax.plot(ccp_alpha_values, train_scores, marker='o', label="training accuracy", drawstyle="steps-post")
ax.plot(ccp_alpha_values, test_scores, marker='o', label="testing accuracy", drawstyle="steps-post")
ax.legend()

# %%
clf = DecisionTreeClassifier(random_state=42, ccp_alpha=0.01)
clf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01, random_state=42)

# %%
pred = clf.predict(xtest)
accuracy_score(ytest, pred)
# Out:
# 0.9649122807017544

# %%
clf.score(xtrain, ytrain)
# Out:
# 0.9824120603015075

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled=True)
# Out:
# [Text(0.4230769230769231, 0.9, 'x[7] <= 0.051\ngini = 0.468\nsamples = 398\nvalue = [249, 149]'),
#  Text(0.15384615384615385, 0.7, 'x[20] <= 16.83\ngini = 0.1\nsamples = 245\nvalue = [232, 13]'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.043\nsamples = 230\nvalue = [225, 5]'),
#  Text(0.23076923076923078, 0.5, 'x[1] <= 16.19\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.15384615384615385, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3076923076923077, 0.3, 'gini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.6923076923076923, 0.7, 'x[21] <= 20.405\ngini = 0.198\nsamples = 153\nvalue = [17, 136]'),
#  Text(0.5384615384615384, 0.5, 'x[20] <= 18.145\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.46153846153846156, 0.3, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.6153846153846154, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8461538461538461, 0.5, 'x[23] <= 718.65\ngini = 0.096\nsamples = 139\nvalue = [7, 132]'),
#  Text(0.7692307692307693, 0.3, 'x[21] <= 25.925\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.6923076923076923, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8461538461538461, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9230769230769231, 0.3, 'gini = 0.0\nsamples = 126\nvalue = [0, 126]')]

# %% [markdown]
# # XGBoost

# %%
#random & grid
#before performance & after performance

# %%
#xtrain, xtest, ytrain, ytest

# %%
#!pip install xgboost

# %% [markdown]
# # ADA Boost

# %%
#random & grid
#before performance & after performance

# %% [markdown]
# # CatBoost

# %%
#random & grid
#before performance & after performance
