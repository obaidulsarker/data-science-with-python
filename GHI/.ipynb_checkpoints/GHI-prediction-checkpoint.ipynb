# %% [markdown]
# ## Load Data

# %%
import pandas as pd

# Load the Excel file
file_path = 'data/sky_camera.xlsx'
data = pd.read_excel(file_path)

# %%
# Display the first few rows of the dataset
data.head()
# Out:
#               File Name  File Name.1 Timestamp  real GHI
# 0  20221031013000_0.jpg          130      1:30       0.0
# 1  20221031013100_0.jpg          131      1:31       0.0
# 2  20221031013200_0.jpg          132      1:32       0.0
# 3  20221031013300_0.jpg          133      1:33       0.0
# 4  20221031013400_0.jpg          134      1:34       0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   File Name    880 non-null    object
#  1   File Name.1  880 non-null    int64
#  2   Timestamp    880 non-null    object
#  3   real GHI     880 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 27.6+ KB

# %%
data.shape
# Out:
# (880, 4)

# %% [markdown]
# ##  Preprocess the Data

# %%
image_path='data/images'

# Create the new 'image_path' column
data['image_path'] = data['File Name'].apply(lambda x: f'data/images/{x}')

# %%
data.head()
# Out:
#               File Name  File Name.1 Timestamp  real GHI  \
# 0  20221031013000_0.jpg          130      1:30       0.0
# 1  20221031013100_0.jpg          131      1:31       0.0
# 2  20221031013200_0.jpg          132      1:32       0.0
# 3  20221031013300_0.jpg          133      1:33       0.0
# 4  20221031013400_0.jpg          134      1:34       0.0
#
#                          image_path
# 0  data/images/20221031013000_0.jpg
# 1  data/images/20221031013100_0.jpg
# 2  data/images/20221031013200_0.jpg
# 3  data/images/20221031013300_0.jpg
# 4  data/images/20221031013400_0.jpg

# %%
data.columns
# Out:
# Index(['File Name', 'File Name.1', 'Timestamp', 'real GHI', 'image_path'], dtype='object')

# %%
data.rename(columns={
    'File Name' : 'file_name',
    'File Name.1' : 'file_name1',
    'Timestamp': 'timestamp',
    'real GHI' : 'ghi'
}, inplace=True)

# %%
data.head()
# Out:
#               file_name  file_name1 timestamp  ghi  \
# 0  20221031013000_0.jpg         130      1:30  0.0
# 1  20221031013100_0.jpg         131      1:31  0.0
# 2  20221031013200_0.jpg         132      1:32  0.0
# 3  20221031013300_0.jpg         133      1:33  0.0
# 4  20221031013400_0.jpg         134      1:34  0.0
#
#                          image_path
# 0  data/images/20221031013000_0.jpg
# 1  data/images/20221031013100_0.jpg
# 2  data/images/20221031013200_0.jpg
# 3  data/images/20221031013300_0.jpg
# 4  data/images/20221031013400_0.jpg

# %%
import os

# Function to check if the file exists
def check_file_existence(file_path):
    return 'Yes' if os.path.exists(file_path) else 'No'

# %%
# Create the new 'file_existance' column
data['file_existance'] = data['image_path'].apply(check_file_existence)

# %%
data.head()
# Out:
#               file_name  file_name1 timestamp  ghi  \
# 0  20221031013000_0.jpg         130      1:30  0.0
# 1  20221031013100_0.jpg         131      1:31  0.0
# 2  20221031013200_0.jpg         132      1:32  0.0
# 3  20221031013300_0.jpg         133      1:33  0.0
# 4  20221031013400_0.jpg         134      1:34  0.0
#
#                          image_path file_existance
# 0  data/images/20221031013000_0.jpg            Yes
# 1  data/images/20221031013100_0.jpg            Yes
# 2  data/images/20221031013200_0.jpg            Yes
# 3  data/images/20221031013300_0.jpg            Yes
# 4  data/images/20221031013400_0.jpg            Yes

# %%
data_filtered = data[data['file_existance'] == 'Yes']

# %%
data_filtered.shape
# Out:
# (880, 6)

# %%
# Find Invalid Data where no image found
invalid_data = data[data['file_existance'] == 'No']

# %%
# Save invalid data into csv
invalid_data.to_csv('data/invalid_data.csv',  header=True, index=False)

# %%
#!pip3 install opencv-python
#!pip install tensorflow

# %%
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Assuming 'data' DataFrame contains 'image_path' and 'ghi' columns
# Preprocess images and GHI values
image_size = (128, 128)  # Resize to 128x128

# %%
def preprocess_image(img_path):
    image = cv2.imread(img_path)
    image = cv2.resize(image, image_size)
    image = image / 255.0  # Normalize to [0, 1]
    return image

# %%
# Read images and GHI values
# -- features
images = np.array([preprocess_image(path) for path in data_filtered['image_path'].values])

# -- Target 
ghi_values = data_filtered['ghi'].values

# %%
# Normalize GHI values
ghi_values = ghi_values / ghi_values.max()

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(images, ghi_values, test_size=0.2, random_state=42)

# Build a CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='linear')  # Regression output
])

model.compile(optimizer=Adam(), loss='mean_squared_error', metrics=['mae'])
#model.compile(optimizer=Adam(), loss='mean_squared_error',  metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\obaidulhaque.sarker\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)                    │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,304,769 (12.61 MB)
#  Trainable params: 3,304,769 (12.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - loss: 2.6802 - mae: 0.9429 - val_loss: 0.1183 - val_mae: 0.3068
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 246ms/step - loss: 0.1371 - mae: 0.3093 - val_loss: 0.0588 - val_mae: 0.2164
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - loss: 0.0800 - mae: 0.2243 - val_loss: 0.0192 - val_mae: 0.1132
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - loss: 0.0628 - mae: 0.1780 - val_loss: 0.0108 - val_mae: 0.0837
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - loss: 0.0540 - mae: 0.1607 - val_loss: 0.0213 - val_mae: 0.1165
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - loss: 0.0469 - mae: 0.1432 - val_loss: 0.0095 - val_mae: 0.0799
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 0.0564 - mae: 0.1660 - val_loss: 0.0082 - val_mae: 0.0686
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - loss: 0.0463 - mae: 0.1499 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 0.0400 - mae: 0.1372 - val_loss: 0.0132 - val_mae: 0.0893
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 0.0444 - mae: 0.1337 - val_loss: 0.0068 - val_mae: 0.0627
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - loss: 0.0523 - mae: 0.1497 - val_loss: 0.0067 - val_mae: 0.0619
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - loss: 0.0428 - mae: 0.1363 - val_loss: 0.0054 - val_mae: 0.0547
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - loss: 0.0366 - mae: 0.1302 - val_loss: 0.0183 - val_mae: 0.1066
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 0.0392 - mae: 0.1321 - val_loss: 0.0055 - val_mae: 0.0568
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - loss: 0.0428 - mae: 0.1384 - val_loss: 0.0043 - val_mae: 0.0441
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 0.0513 - mae: 0.1510 - val_loss: 0.0064 - val_mae: 0.0633
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 0.0435 - mae: 0.1365 - val_loss: 0.0048 - val_mae: 0.0517
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s
# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


# Evaluate the model
#loss, mae = model.evaluate(X_test, y_test)
#print(f'Validation MAE: {mae}')

# Assume 'model' is your trained model
predictions = model.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Mean Absolute Error (MAE): 0.07701955847712483
# Mean Squared Error (MSE): 0.008262972459457616
# R-squared (R²): 0.9406960055952376

# %%
## Visualize Results

import matplotlib.pyplot as plt

# Scatter plot of actual vs. predicted GHI values
plt.scatter(y_test, predictions, alpha=0.5)
plt.xlabel('Actual GHI')
plt.ylabel('Predicted GHI')
plt.title('Actual vs Predicted GHI')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Diagonal line
plt.show()

# Plot residuals
residuals = y_test - predictions
plt.hist(residuals, bins=50, edgecolor='k')
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
plt.show()

# %%
# Plot actual vs predicted GHI values
import matplotlib.pyplot as plt

# Plotting actual vs predicted GHI values
plt.figure(figsize=(14, 7))

# Plot actual GHI values
plt.plot(y_test, label='Actual GHI', color='blue', linewidth=2)

# Plot predicted GHI values
plt.plot(predictions, label='Predicted GHI', color='red', linestyle='--', linewidth=2)

# Adding labels and title
plt.xlabel('Sample Index')
plt.ylabel('GHI Value')
plt.title('Actual vs Predicted GHI Values')
plt.legend()

# Show the plot
plt.show()

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, Input
from tensorflow.keras.optimizers import Adam

X_val=X_test
y_val=y_test

# Modify the input shape to (128, 128, 3)
input_tensor = Input(shape=(128, 128, 3))

# Load ResNet50 with custom input shape
base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)

# Add custom layers on top
x = Flatten()(base_model.output)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
predictions = Dense(1)(x)  # Output layer for regression

# Compile the model
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

# Assuming X_train and y_train are the image data and labels
# Fit the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

# Evaluate the model
val_loss, val_mae = model.evaluate(X_val, y_val)
print(f'Validation MAE: {val_mae}')

# Predictions
predictions = model.predict(X_test)

# Plot Actual vs Predicted
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(y_test, label='Actual GHI', color='blue', linewidth=2)
plt.plot(predictions, label='Predicted GHI', color='red', linestyle='--', linewidth=2)
plt.xlabel('Sample Index')
plt.ylabel('GHI Value')
plt.title('Actual vs Predicted GHI Values')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 118s 3s/step - loss: 1201.2242 - mae: 13.8181 - val_loss: 137.7766 - val_mae: 11.7316
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.7409 - mae: 0.6615 - val_loss: 232.3179 - val_mae: 15.2370
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.1125 - mae: 0.2685 - val_loss: 27.6458 - val_mae: 5.2450
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.0572 - mae: 0.1897 - val_loss: 4.7633 - val_mae: 2.1505
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.0404 - mae: 0.1559 - val_loss: 1.6785 - val_mae: 1.2408
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.0426 - mae: 0.1525 - val_loss: 0.9142 - val_mae: 0.8805
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.0302 - mae: 0.1274 - val_loss: 0.6201 - val_mae: 0.6927
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.0222 - mae: 0.1123 - val_loss: 0.5018 - val_mae: 0.6009
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - loss: 0.0239 - mae: 0.1133 - val_loss: 0.4422 - val_mae: 0.5494
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step
50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - loss: 0.0053 - mae: 0.0429 - val_loss: 0.1449 - val_mae: 0.3241
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - loss: 0.0079 - mae: 0.0487 - val_loss: 0.1520 - val_mae: 0.3304
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - loss: 0.0056 - mae: 0.0455 - val_loss: 0.1548 - val_mae: 0.3359
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - loss: 0.0057 - mae: 0.0513 - val_loss: 0.1564 - val_mae: 0.3298
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 77s 4s/step - loss: 0.0060 - mae: 0.0498 - val_loss: 0.1594 - val_mae: 0.3263
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - loss: 0.0051 - mae: 0.0436 - val_loss: 0.1600 - val_mae: 0.3226
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - loss: 0.0036 - mae: 0.0386 - val_loss: 0.1708 - val_mae: 0.3339
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - loss: 0.0045 - mae: 0.0402 - val_loss: 0.1729 - val_mae: 0.3315
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - loss: 0.0046 - mae: 0.0419 - val_loss: 0.1842 - val_mae: 0.3358
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - loss: 0.0040 - mae: 0.0411 - val_loss: 0.1877 - val_mae: 0.3371
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - loss: 0.0040 - mae: 0.0388 - val_loss: 0.1613 - val_mae: 0.3133
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - loss: 0.0052 - mae: 0.0419 - val_loss: 0.1786 - val_mae: 0.3214
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 474ms/step - loss: 0.1750 - mae: 0.3202
# Validation MAE: 0.3213772475719452
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step

# %%
predictions
# Out:
# array([[ 0.14225197],
#        [ 0.08453087],
#        [ 0.13715531],
#        [ 0.12882683],
#        [ 0.05038521],
#        [ 0.20310247],
#        [ 0.23418203],
#        [ 0.21129987],
#        [ 0.10315048],
#        [ 0.07611769],
#        [ 0.19560452],
#        [ 0.20216462],
#        [ 0.0805748 ],
#        [ 0.14450154],
#        [ 0.23688783],
#        [ 0.01348314],
#        [ 0.22227156],
#        [ 0.04867037],
#        [ 0.05361716],
#        [ 0.18332228],
#        [ 0.20705378],
#        [ 0.18179545],
#        [ 0.1239698 ],
#        [ 0.10591424],
#        [ 0.07840817],
#        [ 0.20326659],
#        [ 0.13561048],
#        [ 0.10611968],
#        [ 0.20271693],
#        [ 0.11036169],
#        [ 0.0017507 ],
#        [ 0.12105335],
#        [ 0.06477689],
#        [ 0.19294545],
#        [ 0.22917669],
#        [ 0.12942418],
#        [ 0.12907793],
#        [ 0.12183651],
#        [ 0.12157551],
#        [ 0.23435044],
#        [ 0.23557776],
#        [ 0.08955571],
#        [ 0.13415872],
#        [ 0.03649488],
#        [ 0.04543028],
#        [ 0.04243608],
#        [ 0.11822983],
#        [ 0.23676494],
#        [ 0.12731199],
#        [ 0.23300774],
#        [ 0.2360324 ],
#        [ 0.23734656],
#        [ 0.1111031 ],
#        [ 0.2341419 ],
#        [ 0.07261854],
#        [ 0.22269048],
#        [ 0.19277658],
#        [ 0.24111323],
#        [ 0.21470782],
#        [ 0.14211395],
#        [ 0.11495482],
#        [ 0.20559052],
#        [ 0.13401404],
#        [ 0.124115  ],
#        [ 0.20111991],
#        [ 0.08648524],
#        [ 0.2369928 ],
#        [ 0.21056464],
#        [ 0.08061003],
#        [ 0.17420787],
#        [ 0.12408292],
#        [ 0.23625796],
#        [ 0.04632631],
#        [ 0.2198314 ],
#        [ 0.2419925 ],
#        [ 0.07796465],
#        [ 0.19286898],
#        [ 0.09400315],
#        [ 0.20776986],
#        [ 0.20553504],
#        [ 0.23640773],
#        [ 0.16877072],
#        [ 0.19505519],
#        [ 0.05657902],
#        [ 0.2174246 ],
#        [ 0.2190665 ],
#        [ 0.23970729],
#        [ 0.17327823],
#        [ 0.08149971],
#        [ 0.17542663],
#        [ 0.07593571],
#        [ 0.14354977],
#        [ 0.06744738],
#        [ 0.12982213],
#        [ 0.02242137],
#        [ 0.14348331],
#        [ 0.15356149],
#        [ 0.17582725],
#        [ 0.21821435],
#        [ 0.20775817],
#        [ 0.1041948 ],
#        [ 0.24316849],
#        [ 0.04127425],
#        [ 0.15403408],
#        [ 0.09601852],
#        [ 0.13358796],
#        [ 0.22047493],
#        [ 0.21250516],
#        [ 0.07279352],
#        [ 0.11453227],
#        [ 0.12305424],
#        [ 0.24281341],
#        [ 0.23771489],
#        [ 0.12937717],
#        [ 0.2291171 ],
#        [ 0.16773266],
#        [ 0.17447037],
#        [ 0.23181379],
#        [ 0.14840394],
#        [ 0.03527284],
#        [ 0.17111637],
#        [ 0.04131136],
#        [ 0.16214228],
#        [ 0.10555481],
#        [ 0.05791103],
#        [ 0.13402146],
#        [ 0.23834008],
#        [ 0.19626178],
#        [ 0.23988791],
#        [ 0.10164975],
#        [ 0.22793221],
#        [ 0.14752981],
#        [ 0.00051679],
#        [-0.01724788],
#        [ 0.19732806],
#        [ 0.20750935],
#        [ 0.22337091],
#        [ 0.05023964],
#        [ 0.0594987 ],
#        [ 0.09255952],
#        [ 0.09371573],
#        [ 0.05595801],
#        [ 0.14469033],
#        [ 0.16465074],
#        [ 0.25470787],
#        [ 0.20052831],
#        [ 0.13128057],
#        [ 0.16097118],
#        [ 0.01550889],
#        [ 0.01918852],
#        [ 0.14586355],
#        [ 0.21719591],
#        [ 0.20728545],
#        [ 0.15859641],
#        [ 0.07896239],
#        [ 0.20672077],
#        [ 0.07002985],
#        [ 0.17868927],
#        [ 0.22429484],
#        [ 0.00968194],
#        [ 0.0515786 ],
#        [ 0.02066073],
#        [ 0.22109285],
#        [ 0.17521593],
#        [ 0.05155561],
#        [ 0.21401694],
#        [ 0.07758533],
#        [ 0.11336717],
#        [ 0.13666439],
#        [-0.00214963],
#        [ 0.1006323 ],
#        [ 0.22319588],
#        [ 0.07483942],
#        [ 0.22112781],
#        [ 0.15519257],
#        [ 0.0608679 ]], dtype=float32)

# %%
# Save the model
model.save('models/ghi_prediction_model.keras')
